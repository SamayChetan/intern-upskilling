# %%
import sys
print(sys.executable)
# Out:
# /home/samay/internship-task/.venv/bin/python3

# %%
from ultralytics import YOLO

print("YOLO imported successfully!")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/home/samay/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# YOLO imported successfully!

# %%
model = YOLO("yolov8n.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 14.4MB/s 0.4s.4s<0.0s.7s

# %%
results = model("dog.jpg")
# Out:
# image 1/1 /home/samay/internship-task/dog.jpg: 384x640 1 dog, 155.7ms
# Speed: 2.7ms preprocess, 155.7ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)

# %%
results[0].show()

# %%
names = model.names

for box in results[0].boxes:
    class_id = int(box.cls[0])
    confidence = float(box.conf[0])

    print(f"{names[class_id]} - {confidence:.2f}")
# Out:
# dog - 0.96

# %%
print("Detected Objects:\n")

names = model.names

for box in results[0].boxes:
    class_id = int(box.cls[0])
    confidence = float(box.conf[0])

    print(f"Object: {names[class_id]}")
    print(f"Confidence: {confidence:.2f}")
    print("-" * 30)
# Out:
# Detected Objects:
#
# Object: dog
# Confidence: 0.96
# ------------------------------
